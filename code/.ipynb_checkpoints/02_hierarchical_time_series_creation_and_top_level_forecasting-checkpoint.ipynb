# %%
import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib
from matplotlib import pyplot as plt
from textwrap import wrap


pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option('display.max_colwidth', None)
pd.options.mode.chained_assignment = None  # default='warn'

import pickle
import time
from tqdm import tqdm

from itertools import product

#import googletrans
#from googletrans import Translator
#to avoid instantiate too many translator, we created one instance for the whole notebook
#translator = Translator()


from prophet import Prophet
import itertools
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics

import holidays


import hts.functions
import collections
from hts import HTSRegressor
from hts.hierarchy import HierarchyTree


from sktime.transformations.hierarchical.reconcile import Reconciler
from sktime.transformations.hierarchical.aggregate import Aggregator
from sktime.forecasting.exp_smoothing import ExponentialSmoothing


import logging
logger = logging.getLogger('cmdstanpy')
logger.addHandler(logging.NullHandler())
logger.propagate = False
logger.setLevel(logging.CRITICAL)

# %% [markdown]
# # define functions

# %%
def get_best_hyperparams(data):   
    
    default_best_params = {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.2}
    
    first_cutoff_date = pd.to_datetime('2015-02-1')
    first_nonzero_date = data['y'].ne(0).idxmax()
    
    # return default_best_params if 
    # 1. all values are zero
    # 2. too many values are zero
    if (data['y'] == 0).all() or (first_cutoff_date < first_nonzero_date):
        print( first_nonzero_date)
        print("too many zero values, return default best params")
        return default_best_params
    else:
        param_grid = {  
                'changepoint_prior_scale': [0.01,0.2],
                'seasonality_prior_scale': [0.01,0.5 ],
        }

        # Generate all combinations of parameters
        all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
        rmses = []  # Store the RMSEs for each params here

        # Use cross validation to evaluate all parameters
        cutoffs = pd.to_datetime(['2015-2-1', '2015-6-1'])

        for params in all_params:
            m = Prophet(**params).fit(data)  # Fit model with given params
            df_cv = cross_validation(m, cutoffs=cutoffs, horizon='90 days', parallel="processes")
            df_p = performance_metrics(df_cv, rolling_window=1)
            rmses.append(df_p['rmse'].values[0])

        # Find the best parameters
        tuning_results = pd.DataFrame(all_params)
        tuning_results['rmse'] = rmses

        best_params = all_params[np.argmin(rmses)]
        print(best_params)
        return best_params

# %%
def get_best_preds(df_,   #df_heir_train
                   cat_id  #cat_id in oneshop_cat_list 
                  ):
    #get dataframe
    columns = ['ds', cat_id]
    df = df_.loc[:, columns]
    df.columns = ['ds', 'y']
    
    #get best_params
    best_params = get_best_hyperparams(df)
    
    #create model based on best_params
    m = Prophet(changepoint_prior_scale=best_params['changepoint_prior_scale'], 
                seasonality_prior_scale=best_params['seasonality_prior_scale'], 
                yearly_seasonality=True)
    m.add_country_holidays(country_name='RU')
    m.fit(df)

    #predict and return
    future = m.make_future_dataframe(periods=1, freq='MS')
    forecast = m.predict(future)

    print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(3))
    #fig1 = m.plot(forecast)

    best_preds = forecast.tail(1).yhat.values[0]
    print('best_preds: ', best_preds)
    return best_preds

# %% [markdown]
# # import data from pickle file

# %%
pickle_dict2 = pickle.load(open('../temp/data2.pkl', 'rb'))
df_basegrid = pickle_dict2['df_basegrid']   #concat df_train_m and df_test

# %%
list_shop_id=sorted(df_basegrid['shop_id'].unique())
print(list_shop_id)
print(len(list_shop_id))
# Out:
# [2, 3, 4, 5, 6, 7, 10, 12, 14, 15, 16, 18, 19, 21, 22, 24, 25, 26, 28, 31, 34, 35, 36, 37, 38, 39, 41, 42, 44, 45, 46, 47, 48, 49, 50, 52, 53, 55, 56, 57, 58, 59]
# 42

# %% [markdown]
# # create hierachical time series for all shops

# %%
# %%time

for i in tqdm(range(len(list_shop_id))):
    ################ get one shop dataframe
    #################################################################
    df_oneshop = df_basegrid[df_basegrid['shop_id'] == list_shop_id[i]]

    ##change values in the following columns so that their combinations are more readable
    df_oneshop['date_block_num'] =df_oneshop['date_block_num'].astype(str)
    df_oneshop['item_category_id'] =df_oneshop['item_category_id'].astype(str)
    df_oneshop['shop_id'] =df_oneshop['shop_id'].astype(str)
    df_oneshop['item_id'] =df_oneshop['item_id'].astype(str)
    df_oneshop['item_category_id'] = 'c' + df_oneshop['item_category_id']
    df_oneshop['shop_id'] = 's' + df_oneshop['shop_id']
    df_oneshop['item_id'] = 'i' + df_oneshop['item_id']



    ############### create hierachical time series for the shop
    ##############################################################
    level_names = ['item_category_id','item_id']
    hierarchy = [['item_category_id']]
    df_hier, sum_mat, sum_mat_labels = hts.functions.get_hierarchichal_df(df_oneshop,
                                                                          level_names=level_names,
                                                                          hierarchy=hierarchy,
                                                                          date_colname='year_month',
                                                                          val_colname='item_cnt_month')
    #fill all null value with 0
    df_hier = df_hier.fillna(0)
    df_hier['ds']= df_hier.index

    old_column_list = df_hier.columns
    new_column_list = [old_column_list[-1], *old_column_list[:-1]]
    df_hier = df_hier[new_column_list]

    #df_hier.to_csv(f'../temp/s{list_shop_id[0]}_hier.csv')


    ################ get the hier_dict
    #################################################################

    #get the lists
    oneshop_cat_list = sorted(df_oneshop['item_category_id'].unique())
    oneshop_item_list = sorted(df_oneshop['item_id'].unique())

    #dictionary to hold all level nodes
    hier_dict = {}

    #get level 1 nodes: category nodes
    level_1_nodes = [str(cat_id) for cat_id in oneshop_cat_list]

    #print(level_1_nodes)
    hier_dict['total'] = level_1_nodes

    #get level 2 nodes
    df_hier_columns = sorted(df_hier.columns)
    for node in level_1_nodes: 
        temp_level_2_nodes = list(filter(lambda cat_item: f'{node}_' in cat_item, df_hier_columns))
        hier_dict[node] = temp_level_2_nodes

    tree = HierarchyTree.from_nodes(hier_dict, df_hier, root='total')
    #print(tree)

    sum_mat, sum_mat_labels = hts.functions.to_sum_mat(tree)



    ###########save neccessary object to pickle_dict, 
    ############################################################################
    pickle_dict_oneshop = dict()
    pickle_dict_oneshop['df_hier']=df_hier   #concat df_train_m and df_test
    pickle_dict_oneshop['tree']=tree 
    pickle_dict_oneshop['sum_mat']=sum_mat
    pickle_dict_oneshop['sum_mat_labels']=sum_mat_labels
    pickle_dict_oneshop['oneshop_cat_list']=oneshop_cat_list
    pickle_dict_oneshop['oneshop_item_list']=oneshop_item_list

    pickle.dump(pickle_dict_oneshop, open(f'../temp/s{list_shop_id[i]}_hier.pkl', 'wb'))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [07:28<00:00, 10.67s/it]
# Wall time: 7min 28s

# %% [markdown]
# # forecasting all hierachy time series using prophet

# %% [markdown]
# ### shop_id: 36 only have one month data, won't be feed into forcasting

# %%
list_shop_id_filtered = list_shop_id.copy()
list_shop_id_filtered.remove(36)
print(list_shop_id_filtered)
print(len(list_shop_id_filtered))
# Out:
# [2, 3, 4, 5, 6, 7, 10, 12, 14, 15, 16, 18, 19, 21, 22, 24, 25, 26, 28, 31, 34, 35, 37, 38, 39, 41, 42, 44, 45, 46, 47, 48, 49, 50, 52, 53, 55, 56, 57, 58, 59]
# 41

# %% [markdown]
# ### forecasting all category sales in all shops

# %%
# %%time
    
for shop_id in tqdm(list_shop_id_filtered):
    
    print(f'\n\nforecasting shop: s{shop_id}')
    
    ####read pickle_dict, which store everything
    #############################################
    pickle_dict_oneshop = pickle.load(open(f'../temp/s{shop_id}_hier.pkl', 'rb'))
    df_hier  = pickle_dict_oneshop['df_hier']
    tree = pickle_dict_oneshop['tree']
    sum_mat = pickle_dict_oneshop['sum_mat']
    sum_mat_labels =pickle_dict_oneshop['sum_mat_labels']
    oneshop_cat_list = pickle_dict_oneshop['oneshop_cat_list']
    oneshop_item_list = pickle_dict_oneshop['oneshop_item_list']


    ################### creat train, validation,and test dataset
    ###########################################################################
    df_hier_train = df_hier.loc[df_hier.index <= '2015-10-01']
    df_hier_test = df_hier.loc[df_hier.index == '2015-11-01']


    
    forecasts = pd.DataFrame(columns = df_hier.columns, index=['fake'])
    
    
    ################### forecasting total sales in this shop
    #################################################################
    print('\ngetting best preds for forecast_total_sales')
    forecasts['total'] = [get_best_preds(df_hier_train, 'total')]

    
  
    ################### forecasting all category sales in this shop
    #################################################################
    #dataframe to hold the forecasts
    for cat in oneshop_cat_list:
        print(f'\ngetting best preds for s{shop_id}_', cat)
        forecasts[cat] = [get_best_preds(df_hier_train, cat)]


    ###########save neccessary object to pickle_dict, 
    ############################################################################
    pickle_dict_oneshop_new = dict()
    pickle_dict_oneshop_new['forecasts']=forecasts
    pickle.dump(pickle_dict_oneshop_new, open(f'../temp/s{shop_id}_forecasts.pkl', 'wb'))
# Out:
#   0%|                                                                                           | 0/41 [00:00<?, ?it/s]
# forecasting shop: s2
#
# getting best preds for forecast_total_sales
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01 779.42      696.88      857.77
# 33 2015-10-01 746.11      660.95      827.98
# 34 2015-11-01 903.50      830.79      982.26
# best_preds:  903.5042053640055
#
# getting best preds for s2_ c0
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c11
# 2014-12-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.14       -0.20        0.50
# 33 2015-10-01  0.13       -0.25        0.47
# 34 2015-11-01  0.20       -0.15        0.57
# best_preds:  0.19707196267481153
#
# getting best preds for s2_ c12
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.48       -4.30        9.00
# 33 2015-10-01  0.49       -6.25        6.65
# 34 2015-11-01  8.39        2.04       15.18
# best_preds:  8.385503846194393
#
# getting best preds for s2_ c15
# 2014-06-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.12        0.66        1.58
# 33 2015-10-01  1.49        1.01        1.98
# 34 2015-11-01  0.64        0.17        1.14
# best_preds:  0.6375326908545197
#
# getting best preds for s2_ c16
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.49        0.29        2.71
# 33 2015-10-01  1.09       -0.06        2.33
# 34 2015-11-01  1.10       -0.06        2.30
# best_preds:  1.0994601582221515
#
# getting best preds for s2_ c19
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01 104.82       91.24      119.71
# 33 2015-10-01  83.05       70.48       96.72
# 34 2015-11-01 105.15       91.86      118.17
# best_preds:  105.15065042918641
#
# getting best preds for s2_ c2
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.32       -0.61        3.26
# 33 2015-10-01  0.93       -1.13        2.74
# 34 2015-11-01  2.69        0.69        4.49
# best_preds:  2.6873989631566717
#
# getting best preds for s2_ c20
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01 110.82       86.81      135.96
# 33 2015-10-01 110.45       85.04      135.33
# 34 2015-11-01 114.98       90.59      138.69
# best_preds:  114.98240814810765
#
# getting best preds for s2_ c21
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.54        0.11        4.93
# 33 2015-10-01  2.51       -0.03        4.93
# 34 2015-11-01  2.63        0.19        5.02
# best_preds:  2.627460325929458
#
# getting best preds for s2_ c22
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  9.02        5.38       12.54
# 33 2015-10-01  8.39        4.82       11.87
# 34 2015-11-01  8.58        5.01       12.19
# best_preds:  8.583632444706028
#
# getting best preds for s2_ c23
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 71.01       49.11       90.98
# 33 2015-10-01 68.71       46.64       88.68
# 34 2015-11-01 70.42       49.25       92.31
# best_preds:  70.41996973469843
#
# getting best preds for s2_ c24
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 18.84       13.41       24.65
# 33 2015-10-01 20.03       13.96       25.31
# 34 2015-11-01 25.42       19.32       31.36
# best_preds:  25.41766987737436
#
# getting best preds for s2_ c25
# 2015-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  7.95        4.57       11.19
# 33 2015-10-01  9.20        6.23       12.58
# 34 2015-11-01  9.70        6.56       12.93
# best_preds:  9.695444618566526
#
# getting best preds for s2_ c26
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c27
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c28
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 44.98       22.23       67.29
# 33 2015-10-01 46.92       24.16       71.15
# 34 2015-11-01 50.67       28.76       75.57
# best_preds:  50.667893915360025
#
# getting best preds for s2_ c29
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  4.17       -2.37       10.52
# 33 2015-10-01  4.20       -2.35       10.73
# 34 2015-11-01  4.99       -1.46       11.79
# best_preds:  4.990458652239091
#
# getting best preds for s2_ c3
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 17.38        5.68       28.06
# 33 2015-10-01 16.73        5.49       28.53
# 34 2015-11-01 16.92        5.61       28.04
# best_preds:  16.918751300637304
#
# getting best preds for s2_ c30
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01  91.56       75.95      108.44
# 33 2015-10-01 110.26       94.72      126.72
# 34 2015-11-01 109.83       95.23      125.94
# best_preds:  109.83088782273337
#
# getting best preds for s2_ c31
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c33
# 2014-06-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.27        0.90        3.60
# 33 2015-10-01  2.33        0.93        3.62
# 34 2015-11-01  3.33        2.00        4.64
# best_preds:  3.333496184082371
#
# getting best preds for s2_ c34
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c35
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  9.42        3.90       14.67
# 33 2015-10-01  7.36        1.92       12.92
# 34 2015-11-01 14.04        8.56       18.99
# best_preds:  14.03825034739753
#
# getting best preds for s2_ c36
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c37
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 24.53       15.67       32.57
# 33 2015-10-01 25.65       17.64       33.95
# 34 2015-11-01 25.67       16.97       34.06
# best_preds:  25.669599685332685
#
# getting best preds for s2_ c38
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 17.26       13.37       21.52
# 33 2015-10-01  9.83        5.79       14.11
# 34 2015-11-01 13.97        9.87       18.01
# best_preds:  13.969708854501341
#
# getting best preds for s2_ c40
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 45.31       40.41       49.96
# 33 2015-10-01 62.51       57.70       67.60
# 34 2015-11-01 49.49       44.42       54.65
# best_preds:  49.487794307098646
#
# getting best preds for s2_ c41
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.25        0.67        3.86
# 33 2015-10-01  3.57        1.86        5.22
# 34 2015-11-01  4.16        2.44        5.80
# best_preds:  4.161186896000797
#
# getting best preds for s2_ c42
# 2015-05-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  8.65        7.75        9.53
# 33 2015-10-01  8.72        7.85        9.66
# 34 2015-11-01 10.82        9.97       11.77
# best_preds:  10.816719657063837
#
# getting best preds for s2_ c43
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.03       -0.52        0.54
# 33 2015-10-01  0.09       -0.44        0.63
# 34 2015-11-01  0.05       -0.48        0.57
# best_preds:  0.04605302410733528
#
# getting best preds for s2_ c44
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c45
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c47
# 2015-06-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  5.15        3.35        6.86
# 33 2015-10-01 10.43        8.72       12.27
# 34 2015-11-01  5.43        3.50        7.31
# best_preds:  5.427970690192229
#
# getting best preds for s2_ c49
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 11.31        4.93       17.03
# 33 2015-10-01  8.85        2.45       14.94
# 34 2015-11-01  2.43       -3.83        8.40
# best_preds:  2.434516636032519
#
# getting best preds for s2_ c5
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 -0.08       -0.79        0.67
# 33 2015-10-01 -0.06       -0.80        0.62
# 34 2015-11-01 -0.06       -0.81        0.64
# best_preds:  -0.06068760168315285
#
# getting best preds for s2_ c54
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c55
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 13.78       -8.25       35.30
# 33 2015-10-01 13.97       -7.90       35.04
# 34 2015-11-01 14.60       -6.49       39.12
# best_preds:  14.595221405253376
#
# getting best preds for s2_ c56
# 2014-08-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.29       -0.23        0.91
# 33 2015-10-01  0.68        0.11        1.30
# 34 2015-11-01  2.09        1.48        2.66
# best_preds:  2.0850864302992216
#
# getting best preds for s2_ c57
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.30       -0.97        1.66
# 33 2015-10-01  0.30       -0.91        1.56
# 34 2015-11-01  0.31       -1.05        1.50
# best_preds:  0.30835940626800423
#
# getting best preds for s2_ c58
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.50       -0.02        1.02
# 33 2015-10-01  0.13       -0.40        0.63
# 34 2015-11-01  0.69        0.19        1.20
# best_preds:  0.6899178188740246
#
# getting best preds for s2_ c6
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  7.67        4.52       10.91
# 33 2015-10-01  6.91        3.78       10.00
# 34 2015-11-01  4.82        1.63        7.97
# best_preds:  4.823818737498042
#
# getting best preds for s2_ c60
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c61
# 2014-06-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 10.03        8.00       12.19
# 33 2015-10-01  5.91        3.80        7.93
# 34 2015-11-01  8.47        6.29       10.75
# best_preds:  8.465798232042761
#
# getting best preds for s2_ c62
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 -0.29       -1.25        0.64
# 33 2015-10-01 -0.23       -1.24        0.72
# 34 2015-11-01  0.97        0.01        1.84
# best_preds:  0.9710760358449515
#
# getting best preds for s2_ c63
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 32.93       27.50       37.61
# 33 2015-10-01 23.94       18.73       29.10
# 34 2015-11-01 29.63       25.07       34.35
# best_preds:  29.629474788968704
#
# getting best preds for s2_ c64
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 13.79        7.63       20.50
# 33 2015-10-01 13.78        6.68       20.56
# 34 2015-11-01 13.62        7.18       20.06
# best_preds:  13.624019088048806
#
# getting best preds for s2_ c65
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 11.07        6.96       15.04
# 33 2015-10-01 11.24        7.31       14.90
# 34 2015-11-01 11.72        7.95       15.94
# best_preds:  11.717706067543366
#
# getting best preds for s2_ c67
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.67       -0.92        6.20
# 33 2015-10-01  5.56        1.84        8.93
# 34 2015-11-01  4.62        1.06        7.95
# best_preds:  4.615465275511156
#
# getting best preds for s2_ c69
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  8.30        4.38       12.52
# 33 2015-10-01 10.44        6.57       14.47
# 34 2015-11-01 12.45        8.59       16.45
# best_preds:  12.445318204942645
#
# getting best preds for s2_ c7
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  6.42        3.84        9.42
# 33 2015-10-01  5.00        2.14        7.75
# 34 2015-11-01  5.28        2.36        8.08
# best_preds:  5.27653031168471
#
# getting best preds for s2_ c70
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 15.53       11.38       19.76
# 33 2015-10-01 21.01       16.71       25.36
# 34 2015-11-01 27.27       23.15       31.68
# best_preds:  27.265156538027952
#
# getting best preds for s2_ c71
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 12.28        5.29       18.36
# 33 2015-10-01 11.54        5.49       18.52
# 34 2015-11-01 17.21       11.15       23.45
# best_preds:  17.21252966892977
#
# getting best preds for s2_ c72
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 17.79       11.17       24.95
# 33 2015-10-01 18.04       10.60       25.73
# 34 2015-11-01 19.68       12.10       26.39
# best_preds:  19.680107476797918
#
# getting best preds for s2_ c73
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.14        1.18        5.09
# 33 2015-10-01  3.22        1.32        5.00
# 34 2015-11-01  2.09        0.13        4.10
# best_preds:  2.0862043873307967
#
# getting best preds for s2_ c74
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c75
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  6.35        3.01        9.44
# 33 2015-10-01  6.10        2.85        9.39
# 34 2015-11-01  6.29        3.10        9.45
# best_preds:  6.294901935196603
#
# getting best preds for s2_ c76
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c77
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 -0.02       -0.22        0.19
# 33 2015-10-01 -0.02       -0.22        0.18
# 34 2015-11-01 -0.02       -0.23        0.17
# best_preds:  -0.023877221104369097
#
# getting best preds for s2_ c78
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s2_ c79
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 12.48        5.18       18.88
# 33 2015-10-01 12.78        5.65       19.97
# 34 2015-11-01 13.35        6.23       20.09
# best_preds:  13.349476758692735
#
# getting best preds for s2_ c83
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.71       -2.25        3.41
# 33 2015-10-01  0.66       -2.49        3.50
# 34 2015-11-01  0.61       -2.24        3.62
# best_preds:  0.6090126744350847
#
# getting best preds for s2_ c9
# 2013-01-01 00:00:00
# too many zero values, return default best params
#   2%|█▉                                                                              | 1/41 [14:38<9:45:56, 878.91s/it]
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
#
# forecasting shop: s3
#
# getting best preds for forecast_total_sales
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01 592.86      553.91      633.02
# 33 2015-10-01 571.53      533.50      608.44
# 34 2015-11-01 672.31      632.20      711.79
# best_preds:  672.3099260108935
#
# getting best preds for s3_ c0
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c11
# 2015-02-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.14       -0.13        0.39
# 33 2015-10-01  0.14       -0.12        0.38
# 34 2015-11-01  0.22       -0.04        0.48
# best_preds:  0.2183571290696267
#
# getting best preds for s3_ c12
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.31       -2.03        6.42
# 33 2015-10-01  1.33       -2.75        5.58
# 34 2015-11-01 10.15        6.34       13.86
# best_preds:  10.152110183213871
#
# getting best preds for s3_ c15
# 2014-08-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.52        0.16        0.92
# 33 2015-10-01  0.11       -0.28        0.51
# 34 2015-11-01  0.17       -0.24        0.58
# best_preds:  0.17414372966074831
#
# getting best preds for s3_ c16
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.81        1.10        2.55
# 33 2015-10-01  1.46        0.74        2.24
# 34 2015-11-01  0.69       -0.02        1.40
# best_preds:  0.6891879094311766
#
# getting best preds for s3_ c19
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 59.22       52.61       66.64
# 33 2015-10-01 44.27       37.14       51.33
# 34 2015-11-01 49.65       42.50       57.41
# best_preds:  49.65314683552417
#
# getting best preds for s3_ c2
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.46        0.97        5.82
# 33 2015-10-01  2.21       -0.47        4.69
# 34 2015-11-01  6.76        4.26        9.54
# best_preds:  6.763309007613595
#
# getting best preds for s3_ c20
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 80.04       60.79      100.00
# 33 2015-10-01 81.71       62.63      101.53
# 34 2015-11-01 87.63       68.64      108.28
# best_preds:  87.63491935233625
#
# getting best preds for s3_ c21
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.55        0.43        4.65
# 33 2015-10-01  2.49        0.43        4.77
# 34 2015-11-01  2.64        0.37        4.83
# best_preds:  2.6373156233578983
#
# getting best preds for s3_ c22
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  8.66        4.70       12.29
# 33 2015-10-01  8.83        5.05       12.83
# 34 2015-11-01  9.11        5.10       13.00
# best_preds:  9.105510592445023
#
# getting best preds for s3_ c23
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 71.17       66.05       75.95
# 33 2015-10-01 41.18       35.94       46.52
# 34 2015-11-01 58.28       53.18       62.88
# best_preds:  58.280141042003606
#
# getting best preds for s3_ c24
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 15.70       12.59       18.96
# 33 2015-10-01 17.52       14.34       20.66
# 34 2015-11-01 20.35       17.12       23.62
# best_preds:  20.350421840976537
#
# getting best preds for s3_ c25
# 2014-12-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.87        1.03        2.74
# 33 2015-10-01  1.07        0.23        1.88
# 34 2015-11-01  1.91        1.12        2.81
# best_preds:  1.906773459523458
#
# getting best preds for s3_ c26
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c27
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c28
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 27.09       13.69       41.15
# 33 2015-10-01 32.33       18.22       45.63
# 34 2015-11-01 58.40       44.59       72.20
# best_preds:  58.401357926095955
#
# getting best preds for s3_ c29
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.24       -0.17        4.76
# 33 2015-10-01  2.22       -0.21        4.47
# 34 2015-11-01  2.48       -0.12        4.91
# best_preds:  2.4830616673179358
#
# getting best preds for s3_ c3
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 17.43       13.62       21.08
# 33 2015-10-01 14.78       11.21       18.67
# 34 2015-11-01 17.30       13.83       20.91
# best_preds:  17.29925411531705
#
# getting best preds for s3_ c30
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01 123.89      104.13      145.38
# 33 2015-10-01 101.12       81.53      121.14
# 34 2015-11-01 128.39      109.26      148.32
# best_preds:  128.39152911826613
#
# getting best preds for s3_ c31
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c33
# 2014-12-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.34        2.08        4.62
# 33 2015-10-01  4.69        3.43        6.03
# 34 2015-11-01  4.49        3.21        5.76
# best_preds:  4.491571886611545
#
# getting best preds for s3_ c34
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c35
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 20.32       13.07       27.57
# 33 2015-10-01 20.91       13.34       28.39
# 34 2015-11-01 21.92       14.50       29.22
# best_preds:  21.91887100091106
#
# getting best preds for s3_ c36
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c37
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 21.10       14.91       26.37
# 33 2015-10-01 22.20       15.86       28.04
# 34 2015-11-01 22.37       16.14       28.30
# best_preds:  22.367105363535018
#
# getting best preds for s3_ c38
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  4.22        2.26        6.27
# 33 2015-10-01  6.11        4.13        8.07
# 34 2015-11-01  3.82        1.78        5.75
# best_preds:  3.8218914773478483
#
# getting best preds for s3_ c40
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 53.27       39.27       67.59
# 33 2015-10-01 56.31       42.03       69.78
# 34 2015-11-01 58.12       44.68       71.14
# best_preds:  58.12078171819997
#
# getting best preds for s3_ c41
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.77        2.18        5.31
# 33 2015-10-01  4.25        2.61        5.90
# 34 2015-11-01  6.95        5.31        8.57
# best_preds:  6.954614032280476
#
# getting best preds for s3_ c42
# 2015-05-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.02        0.64        1.44
# 33 2015-10-01  1.50        1.13        1.85
# 34 2015-11-01  1.22        0.82        1.60
# best_preds:  1.2237058901535416
#
# getting best preds for s3_ c43
# 2015-02-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.18       -0.28        0.67
# 33 2015-10-01  0.19       -0.29        0.64
# 34 2015-11-01  0.34       -0.13        0.80
# best_preds:  0.3398446145735339
#
# getting best preds for s3_ c44
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c45
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c47
# 2015-07-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.69        1.01        2.35
# 33 2015-10-01  0.45       -0.22        1.13
# 34 2015-11-01  0.85        0.13        1.54
# best_preds:  0.8487099606173991
#
# getting best preds for s3_ c49
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.25        1.27        5.25
# 33 2015-10-01  3.36        1.19        5.32
# 34 2015-11-01  3.33        1.25        5.48
# best_preds:  3.333674150839665
#
# getting best preds for s3_ c5
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.10       -0.19        2.30
# 33 2015-10-01  1.07       -0.16        2.33
# 34 2015-11-01  1.08       -0.21        2.31
# best_preds:  1.0820816327744707
#
# getting best preds for s3_ c54
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c55
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 62.75       41.51       82.23
# 33 2015-10-01 63.96       43.20       84.73
# 34 2015-11-01 66.92       46.13       87.47
# best_preds:  66.92471952083918
#
# getting best preds for s3_ c56
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.07        0.10        2.08
# 33 2015-10-01  1.13        0.20        2.12
# 34 2015-11-01  1.13        0.18        2.09
# best_preds:  1.130138646442089
#
# getting best preds for s3_ c57
# 2015-02-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.17       -0.29        0.61
# 33 2015-10-01  0.58        0.12        1.06
# 34 2015-11-01  0.22       -0.24        0.66
# best_preds:  0.21554405546654848
#
# getting best preds for s3_ c58
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.02       -0.26        0.30
# 33 2015-10-01  0.01       -0.26        0.27
# 34 2015-11-01  0.01       -0.27        0.28
# best_preds:  0.01289496192656866
#
# getting best preds for s3_ c6
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  7.09        4.41        9.81
# 33 2015-10-01  5.09        2.39        7.86
# 34 2015-11-01  7.54        4.84       10.31
# best_preds:  7.536297464141656
#
# getting best preds for s3_ c60
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 -0.05       -0.42        0.36
# 33 2015-10-01 -0.05       -0.50        0.36
# 34 2015-11-01 -0.07       -0.48        0.34
# best_preds:  -0.06644582630073685
#
# getting best preds for s3_ c61
# 2014-08-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.61        0.23        1.00
# 33 2015-10-01  0.25       -0.17        0.62
# 34 2015-11-01  0.39        0.01        0.76
# best_preds:  0.3866537524018591
#
# getting best preds for s3_ c62
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.59       -1.57        2.67
# 33 2015-10-01  0.53       -1.81        2.65
# 34 2015-11-01  0.54       -1.60        2.73
# best_preds:  0.5402755227808201
#
# getting best preds for s3_ c63
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 12.28        8.74       15.92
# 33 2015-10-01 15.50       11.94       18.83
# 34 2015-11-01 13.65       10.33       17.38
# best_preds:  13.654053548517723
#
# getting best preds for s3_ c64
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  6.72        3.11       10.14
# 33 2015-10-01  6.86        3.37       10.16
# 34 2015-11-01  6.98        3.66       10.41
# best_preds:  6.9847808450553055
#
# getting best preds for s3_ c65
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 11.92        7.81       16.75
# 33 2015-10-01 11.80        7.53       16.41
# 34 2015-11-01 12.35        7.74       16.47
# best_preds:  12.354316483004112
#
# getting best preds for s3_ c67
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.45       -0.00        2.97
# 33 2015-10-01  1.42       -0.07        2.85
# 34 2015-11-01  1.52       -0.02        3.13
# best_preds:  1.5178321602810667
#
# getting best preds for s3_ c69
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.58        1.34        5.59
# 33 2015-10-01  3.54        1.36        5.61
# 34 2015-11-01  3.63        1.45        5.80
# best_preds:  3.631376962012358
#
# getting best preds for s3_ c7
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  5.63        4.04        7.24
# 33 2015-10-01  5.29        3.67        6.87
# 34 2015-11-01  5.74        4.08        7.32
# best_preds:  5.741392663533779
#
# getting best preds for s3_ c70
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 10.06        6.32       13.77
# 33 2015-10-01 10.72        7.12       14.42
# 34 2015-11-01 11.67        7.89       15.27
# best_preds:  11.665272208804563
#
# getting best preds for s3_ c71
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 18.54       10.21       27.37
# 33 2015-10-01 18.77        8.96       27.66
# 34 2015-11-01 19.03        9.90       27.60
# best_preds:  19.02677830489069
#
# getting best preds for s3_ c72
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 11.57        6.22       17.04
# 33 2015-10-01 10.42        4.45       15.61
# 34 2015-11-01 18.26       12.24       24.36
# best_preds:  18.256849583382156
#
# getting best preds for s3_ c73
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.94       -0.26        2.24
# 33 2015-10-01  1.50        0.29        2.80
# 34 2015-11-01  0.79       -0.45        2.08
# best_preds:  0.789492781385108
#
# getting best preds for s3_ c74
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c75
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.20        0.97        3.41
# 33 2015-10-01  2.98        1.85        4.27
# 34 2015-11-01  3.68        2.43        4.90
# best_preds:  3.679020509165645
#
# getting best preds for s3_ c76
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c77
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.02       -0.25        0.25
# 33 2015-10-01  0.01       -0.26        0.31
# 34 2015-11-01  0.01       -0.25        0.28
# best_preds:  0.013114304319411128
#
# getting best preds for s3_ c78
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s3_ c79
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 17.15       12.22       22.06
# 33 2015-10-01 16.82       12.09       21.75
# 34 2015-11-01 22.02       17.50       26.69
# best_preds:  22.023465988472505
#
# getting best preds for s3_ c83
# 2014-12-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.53        1.58        5.55
# 33 2015-10-01  3.94        1.81        5.88
# 34 2015-11-01  4.51        2.44        6.54
# best_preds:  4.511443629321568
#
# getting best preds for s3_ c9
# 2013-01-01 00:00:00
# too many zero values, return default best params
#   5%|███▉                                                                            | 2/41 [28:08<9:04:54, 838.33s/it]
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
#
# forecasting shop: s4
#
# getting best preds for forecast_total_sales
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01 724.91      569.69      884.59
# 33 2015-10-01 727.54      563.90      886.16
# 34 2015-11-01 730.03      572.65      887.00
# best_preds:  730.0307925272691
#
# getting best preds for s4_ c0
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s4_ c11
# 2014-12-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.06       -0.14        0.28
# 33 2015-10-01  0.06       -0.16        0.26
# 34 2015-11-01  0.10       -0.14        0.32
# best_preds:  0.10184917616266534
#
# getting best preds for s4_ c12
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.04       -4.76        6.75
# 33 2015-10-01  2.20       -3.76        8.22
# 34 2015-11-01 10.01        4.04       15.14
# best_preds:  10.00747167212562
#
# getting best preds for s4_ c15
# 2014-07-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.93       -0.12        2.00
# 33 2015-10-01  1.57        0.53        2.64
# 34 2015-11-01  1.94        0.86        2.97
# best_preds:  1.936548328114324
#
# getting best preds for s4_ c16
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.78        0.46        3.05
# 33 2015-10-01  0.29       -0.97        1.56
# 34 2015-11-01  1.06       -0.15        2.34
# best_preds:  1.0551161094496606
#
# getting best preds for s4_ c19
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 54.89       43.36       67.00
# 33 2015-10-01 46.81       34.44       58.98
# 34 2015-11-01 49.22       37.91       60.89
# best_preds:  49.22032058165842
#
# getting best preds for s4_ c2
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.78        0.58        7.00
# 33 2015-10-01  3.71        0.70        6.83
# 34 2015-11-01  3.81        0.50        7.06
# best_preds:  3.8147081041274786
#
# getting best preds for s4_ c20
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 38.52       34.29       42.79
# 33 2015-10-01 55.46       51.43       59.74
# 34 2015-11-01 59.51       55.11       63.72
# best_preds:  59.505624189515956
#
# getting best preds for s4_ c21
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.69       -2.45        7.64
# 33 2015-10-01  2.64       -2.34        7.48
# 34 2015-11-01  2.49       -2.28        7.21
# best_preds:  2.4901094325138233
#
# getting best preds for s4_ c22
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  5.94        4.49        7.49
# 33 2015-10-01  3.43        1.84        4.90
# 34 2015-11-01  4.74        3.24        6.23
# best_preds:  4.740851161343395
#
# getting best preds for s4_ c23
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 60.70       44.63       77.87
# 33 2015-10-01 47.24       30.26       65.03
# 34 2015-11-01 71.97       55.68       88.36
# best_preds:  71.96579260825153
#
# getting best preds for s4_ c24
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  8.84        4.23       13.21
# 33 2015-10-01 10.71        6.05       15.36
# 34 2015-11-01 12.10        7.59       16.71
# best_preds:  12.104013690223828
#
# getting best preds for s4_ c25
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  6.20        0.64       11.07
# 33 2015-10-01  6.37        1.14       11.47
# 34 2015-11-01  6.77        1.27       11.91
# best_preds:  6.765627261352394
#
# getting best preds for s4_ c26
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s4_ c27
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s4_ c28
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 43.47       17.81       69.87
# 33 2015-10-01 43.19       17.24       68.48
# 34 2015-11-01 46.14       20.36       72.31
# best_preds:  46.13844228260513
#
# getting best preds for s4_ c29
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.50       -1.15        4.20
# 33 2015-10-01  1.49       -1.23        4.14
# 34 2015-11-01  1.75       -0.85        4.42
# best_preds:  1.7512404426977266
#
# getting best preds for s4_ c3
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  8.53        6.54       10.46
# 33 2015-10-01 10.19        8.15       12.35
# 34 2015-11-01 11.27        9.13       13.38
# best_preds:  11.269912191805815
#
# getting best preds for s4_ c30
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01 131.74       90.21      172.53
# 33 2015-10-01 129.00       88.25      171.69
# 34 2015-11-01 127.19       82.95      170.80
# best_preds:  127.18738630426093
#
# getting best preds for s4_ c31
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s4_ c33
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.54        0.85        2.23
# 33 2015-10-01  1.56        0.88        2.27
# 34 2015-11-01  1.27        0.57        1.91
# best_preds:  1.2675904479631264
#
# getting best preds for s4_ c34
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s4_ c35
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  7.25        4.65        9.83
# 33 2015-10-01  7.50        4.88       10.20
# 34 2015-11-01  4.89        2.33        7.56
# best_preds:  4.888992637973729
#
# getting best preds for s4_ c36
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s4_ c37
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 21.23       14.26       28.73
# 33 2015-10-01 22.74       15.35       29.53
# 34 2015-11-01 23.03       15.64       29.87
# best_preds:  23.03220567034592
#
# getting best preds for s4_ c38
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 10.41        5.91       15.20
# 33 2015-10-01 10.44        5.90       15.17
# 34 2015-11-01 10.61        5.75       15.41
# best_preds:  10.612890598877998
#
# getting best preds for s4_ c40
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 73.40       55.54       89.93
# 33 2015-10-01 77.15       60.49       93.59
# 34 2015-11-01 76.73       60.56       93.46
# best_preds:  76.72787517117187
#
# getting best preds for s4_ c41
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  5.20        2.95        7.24
# 33 2015-10-01  5.35        3.47        7.38
# 34 2015-11-01  5.66        3.79        7.58
# best_preds:  5.657274218008254
#
# getting best preds for s4_ c42
# 2015-05-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.67        0.38        2.98
# 33 2015-10-01  2.59        1.34        3.91
# 34 2015-11-01  2.46        1.13        3.78
# best_preds:  2.464123796981725
#
# getting best preds for s4_ c43
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
# ...
#
# getting best preds for s59_ c23
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 63.58       50.17       76.53
# 33 2015-10-01 51.75       38.39       64.66
# 34 2015-11-01 69.87       56.03       83.32
# best_preds:  69.86893435445373
#
# getting best preds for s59_ c24
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 16.74       11.02       22.37
# 33 2015-10-01 16.18       10.73       21.58
# 34 2015-11-01 23.96       18.10       29.89
# best_preds:  23.95815519570344
#
# getting best preds for s59_ c25
# 2015-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.27        0.69        3.67
# 33 2015-10-01  2.33        0.92        3.87
# 34 2015-11-01  3.40        1.91        4.88
# best_preds:  3.4022709617070843
#
# getting best preds for s59_ c26
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c27
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c28
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01  57.35       35.34       79.14
# 33 2015-10-01  45.59       22.56       67.65
# 34 2015-11-01 105.54       85.22      127.13
# best_preds:  105.54034918318456
#
# getting best preds for s59_ c29
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.93       -0.02        6.17
# 33 2015-10-01  2.94       -0.50        6.07
# 34 2015-11-01  3.32        0.25        6.61
# best_preds:  3.3194028749223414
#
# getting best preds for s59_ c3
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 12.94        4.09       21.83
# 33 2015-10-01 13.10        4.91       21.68
# 34 2015-11-01 13.63        4.99       22.03
# best_preds:  13.63460860215107
#
# getting best preds for s59_ c30
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds   yhat  yhat_lower  yhat_upper
# 32 2015-09-01 174.57      150.12      200.73
# 33 2015-10-01 156.43      130.89      181.32
# 34 2015-11-01 204.11      177.54      228.29
# best_preds:  204.1051866976536
#
# getting best preds for s59_ c31
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c33
# 2015-02-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  5.23        4.03        6.30
# 33 2015-10-01  4.46        3.22        5.57
# 34 2015-11-01  6.00        4.83        7.18
# best_preds:  6.002518087928612
#
# getting best preds for s59_ c34
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c35
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 13.41        6.92       19.63
# 33 2015-10-01 14.66        8.55       21.12
# 34 2015-11-01 25.91       19.77       31.88
# best_preds:  25.907879581628237
#
# getting best preds for s59_ c36
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c37
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 38.43       29.96       47.45
# 33 2015-10-01 41.91       33.73       50.37
# 34 2015-11-01 41.47       32.89       49.76
# best_preds:  41.46580549628026
#
# getting best preds for s59_ c38
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 12.51        8.19       16.81
# 33 2015-10-01 12.71        8.27       16.92
# 34 2015-11-01 12.70        8.30       17.03
# best_preds:  12.703419953732563
#
# getting best preds for s59_ c40
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 75.79       52.60      100.75
# 33 2015-10-01 77.32       54.39      101.36
# 34 2015-11-01 80.81       57.62      102.85
# best_preds:  80.80789030754909
#
# getting best preds for s59_ c41
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  7.10        3.57       10.44
# 33 2015-10-01  7.45        4.07       10.93
# 34 2015-11-01  7.51        3.88       11.13
# best_preds:  7.505029231553532
#
# getting best preds for s59_ c42
# 2015-06-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  4.37        3.94        4.83
# 33 2015-10-01  3.54        3.07        4.00
# 34 2015-11-01  4.88        4.41        5.35
# best_preds:  4.883998142275225
#
# getting best preds for s59_ c43
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.05       -0.40        0.52
# 33 2015-10-01  0.05       -0.43        0.49
# 34 2015-11-01  0.06       -0.43        0.53
# best_preds:  0.055558126206006475
#
# getting best preds for s59_ c44
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c45
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c47
# 2015-06-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  4.85        4.11        5.60
# 33 2015-10-01  5.59        4.86        6.25
# 34 2015-11-01  4.60        3.86        5.26
# best_preds:  4.598762294664221
#
# getting best preds for s59_ c49
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.44        0.16        2.85
# 33 2015-10-01  1.47        0.22        2.73
# 34 2015-11-01  1.54        0.31        2.89
# best_preds:  1.5426296919462685
#
# getting best preds for s59_ c5
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.81       -0.31        1.90
# 33 2015-10-01  0.84       -0.31        1.97
# 34 2015-11-01  0.83       -0.25        1.98
# best_preds:  0.8287668741944747
#
# getting best preds for s59_ c54
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c55
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 82.22       65.37      101.17
# 33 2015-10-01 83.36       65.26      101.13
# 34 2015-11-01 85.95       67.36      103.70
# best_preds:  85.94670985595683
#
# getting best preds for s59_ c56
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.31        1.05        3.60
# 33 2015-10-01  2.33        0.97        3.49
# 34 2015-11-01  2.46        1.07        3.72
# best_preds:  2.464563905871683
#
# getting best preds for s59_ c57
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.35       -0.41        1.12
# 33 2015-10-01  0.41       -0.38        1.15
# 34 2015-11-01  0.37       -0.38        1.11
# best_preds:  0.36826903463549926
#
# getting best preds for s59_ c58
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.88       -0.64        2.35
# 33 2015-10-01  0.93       -0.41        2.41
# 34 2015-11-01  0.94       -0.57        2.47
# best_preds:  0.9410619169368252
#
# getting best preds for s59_ c6
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  5.59        2.96        8.20
# 33 2015-10-01  6.32        3.66        9.14
# 34 2015-11-01  5.59        2.84        8.29
# best_preds:  5.587105312696816
#
# getting best preds for s59_ c60
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.04       -0.23        0.33
# 33 2015-10-01  0.04       -0.24        0.31
# 34 2015-11-01  0.04       -0.25        0.30
# best_preds:  0.04410851611366133
#
# getting best preds for s59_ c61
# 2014-08-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  6.25        4.84        7.69
# 33 2015-10-01  5.60        4.13        7.00
# 34 2015-11-01  7.63        6.33        9.09
# best_preds:  7.628404746467611
#
# getting best preds for s59_ c62
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  1.86       -1.05        4.81
# 33 2015-10-01  1.84       -1.26        4.96
# 34 2015-11-01  1.83       -1.25        4.82
# best_preds:  1.8303922966143493
#
# getting best preds for s59_ c63
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 32.99       24.68       40.70
# 33 2015-10-01 33.28       24.17       41.36
# 34 2015-11-01 34.22       25.16       42.25
# best_preds:  34.224986834127165
#
# getting best preds for s59_ c64
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 10.08        4.42       15.93
# 33 2015-10-01  9.99        4.72       15.54
# 34 2015-11-01  9.53        4.30       14.53
# best_preds:  9.525575150515957
#
# getting best preds for s59_ c65
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 17.92       10.15       25.51
# 33 2015-10-01 18.44       11.18       25.83
# 34 2015-11-01 19.51       11.87       26.89
# best_preds:  19.50570167027403
#
# getting best preds for s59_ c67
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  8.94       -0.30       18.83
# 33 2015-10-01  8.88       -0.11       17.85
# 34 2015-11-01  8.92        0.34       17.95
# best_preds:  8.918478152962997
#
# getting best preds for s59_ c69
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 15.74       11.55       20.53
# 33 2015-10-01 16.04       11.77       20.32
# 34 2015-11-01 19.09       14.79       23.51
# best_preds:  19.09075206222894
#
# getting best preds for s59_ c7
# 2014-09-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  3.32       -0.48        7.29
# 33 2015-10-01  6.02        2.52       10.37
# 34 2015-11-01  5.72        1.88        9.33
# best_preds:  5.721599497803431
#
# getting best preds for s59_ c70
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 15.87       13.21       18.57
# 33 2015-10-01 17.88       15.00       20.51
# 34 2015-11-01 32.50       29.88       35.27
# best_preds:  32.502592774281496
#
# getting best preds for s59_ c71
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 20.43       15.86       24.97
# 33 2015-10-01 20.50       15.64       25.24
# 34 2015-11-01 20.59       15.66       25.51
# best_preds:  20.587962935446214
#
# getting best preds for s59_ c72
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 19.83       11.47       28.59
# 33 2015-10-01 20.46       10.80       29.46
# 34 2015-11-01 21.76       12.99       30.36
# best_preds:  21.760056229472372
#
# getting best preds for s59_ c73
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  2.16       -0.10        4.38
# 33 2015-10-01  2.18       -0.02        4.49
# 34 2015-11-01  2.09       -0.14        4.18
# best_preds:  2.085178554280344
#
# getting best preds for s59_ c74
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c75
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 11.62        9.79       13.39
# 33 2015-10-01 12.10       10.29       13.80
# 34 2015-11-01 26.69       24.90       28.47
# best_preds:  26.69075436249512
#
# getting best preds for s59_ c76
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c77
# {'changepoint_prior_scale': 0.2, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.02       -0.22        0.22
# 33 2015-10-01  0.01       -0.18        0.22
# 34 2015-11-01  0.01       -0.19        0.22
# best_preds:  0.012413543716312968
#
# getting best preds for s59_ c78
# 2013-01-01 00:00:00
# too many zero values, return default best params
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
#
# getting best preds for s59_ c79
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 19.31       12.71       26.19
# 33 2015-10-01 19.97       12.61       26.74
# 34 2015-11-01 20.85       14.68       27.32
# best_preds:  20.852643345135323
#
# getting best preds for s59_ c83
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.5}
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01 12.41        8.00       16.80
# 33 2015-10-01 10.13        5.31       14.93
# 34 2015-11-01 20.72       16.03       25.47
# best_preds:  20.720336926971477
#
# getting best preds for s59_ c9
# 2013-01-01 00:00:00
# too many zero values, return default best params
# 100%|███████████████████████████████████████████████████████████████████████████████| 41/41 [9:55:16<00:00, 871.15s/it]
#            ds  yhat  yhat_lower  yhat_upper
# 32 2015-09-01  0.00       -0.00        0.00
# 33 2015-10-01  0.00       -0.00        0.00
# 34 2015-11-01  0.00       -0.00        0.00
# best_preds:  0.0
# Wall time: 9h 55min 16s
